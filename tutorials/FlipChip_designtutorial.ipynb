# %% [markdown]
# # Flip-Chip Devices in Qiskit Metal
#
# In this notebook, we will construct a device made of a coupled qubit - resonator system in a flip-chip environment. After that, we proceed to analyse them using the EPR technique available in the qiskit metal analyses folder.
#
# The flip-chip device in this notebook is very basic, consisting of two chips separated by a specific distance (that we shall specify later). There are different layout flavours, one way is to place the resonator at the 'bottom' chip or so-called 'control' chip, and the qubit on the 'top' chip or so-called 'qubit' chip.

# %%
from qiskit_metal import designs, MetalGUI

gui = MetalGUI(designs.DesignPlanar())

# %% [markdown]
# > 💡 **Using this tutorial without the Qt GUI**
# >
# > This tutorial uses the desktop `MetalGUI`. To follow along on Colab, Binder, JupyterHub, or any environment where Qt isn't available, **replace any `gui.rebuild()` / `gui.screenshot()` call with `qm.view(design)`** — it renders the design to a matplotlib `Figure` you can display inline or save with `fig.savefig(...)`.
# >
# > See [1.1 Quick start](1-Overview/1.1-Quick-start.ipynb) for a complete runnable walkthrough and [`docs/headless-usage.rst`](../docs/headless-usage.rst) for the full reference.

# %% [markdown]
# ## 1. Building a Flip-Chip Device Design
# We use another class called the <code>DesignFlipChip</code> class. The design workflow is very similar to the one for building planar devices (cf. <code>DesignPlanar</code>), except that there are two chips, and you need to specify which chip you want to draw the device on. At the moment, the two chips are called the 'C_chip' and the 'Q_chip'.

# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, Headings
from qiskit_metal.qlibrary.qubits.transmon_cross import TransmonCross
from qiskit_metal.qlibrary.resonators.readoutres_fc import ReadoutResFC

# suppress deprecation warnings
import warnings

warnings.filterwarnings("ignore", category=Warning)

# %%
# Initialise design
design = designs.DesignFlipChip()
# Specify design name
design.metadata["design_name"] = "FlipChip_Device"
# launch GUI
gui = MetalGUI(design)
# Allow running the same cell here multiple times to overwrite changes
design.overwrite_enabled = True

# %% [markdown]
# Next, we draw an Xmon on the Q-chip, and a readout resonator on the C-chip.

# %%
# delete existing components
design.delete_all_components()

# draw an Xmon on the Q_chip. Notice that I have defined one more item called chip and set it to be the 'Q_chip'
options_cpads = Dict(
    connector_type="0",  # claw type
    claw_length="30um",
    ground_spacing="5um",
    claw_width="10um",
    claw_gap="6um",
)
options = Dict(
    chip="Q_chip",
    cross_width="20um",
    cross_length="150um",
    cross_gap="20um",
    connection_pads=Dict(claw_west=Dict(connector_location="180", **options_cpads)),
)

# position the center of the Xmon at (0,0)
q1_x = "0.0 mm"
q1_y = "0.0 mm"

# build the device, positioned at (q1_x, q1_y)
q1 = TransmonCross(design, "Q1", options=Dict(pos_x=q1_x, pos_y=q1_y, **options))

# rebuild in gui
gui.rebuild()
gui.autoscale()

# %%
# draw a readout resonator on the C_chip. Note that we specify the chip='C_chip'.
# The readout resonator can me made into any shape. Here I opted to use a lambda/4 cpw-based resonator.
# The open-ended end of the resonator has a circular shape with a radius of readout_radius. Change this radius to change the qubit-resonator coupling strength.
# The cpw_width and cpw_gap are the size of the signal line and the ground gap of the cpw transmission line.
# The parameters readout_l1 ... l5, are the lengths of various parts of the cpw.
# arc_step is the length of a line that approximates an arc.
options = Dict(
    chip="C_chip",
    readout_radius="20 um",
    readout_cpw_width="10 um",
    readout_cpw_gap="10 um",
    readout_cpw_turnradius="50 um",
    readout_l1="600 um",
    readout_l2="200 um",
    readout_l3="300 um",
    readout_l4="150 um",
    readout_l5="550 um",
    arc_step="5 um",
)

# the resonator is set to have its origin at the center of the circular patch.
# So we set the qubit and the resonator to share the same coordinate (q1_x, q1_y)
r1 = ReadoutResFC(design, "R1", options=Dict(pos_x=q1_x, pos_y=q1_y, **options))

# rebuild in gui
gui.rebuild()
gui.autoscale()

# %% [markdown]
# ## 2. Preparation Prior to Rendering in ANSYS

# %% [markdown]
# As described before, we have specified two chips in the <code>FlipChipDesign</code> class, i.e. C_chip and Q_chip. This information is stored in the chips variables.

# %%
design.chips
# Out:
# {'C_chip': {'material': 'silicon',
#   'layer_start': '0',
#   'layer_end': '2048',
#   'size': {'center_x': '0.0mm',
#    'center_y': '0.0mm',
#    'center_z': '0.0mm',
#    'size_x': '9mm',
#    'size_y': '9mm',
#    'size_z': '-280um',
#    'sample_holder_top': '890um',
#    'sample_holder_bottom': '1650um'}},
#  'Q_chip': {'material': 'silicon',
#   'layer_start': '0',
#   'layer_end': '2048',
#   'size': {'center_x': '0.0mm',
#    'center_y': '0.0mm',
#    'center_z': '20 um',
#    'size_x': '9mm',
#    'size_y': '9mm',
#    'size_z': '280um',
#    'sample_holder_top': '890um',
#    'sample_holder_bottom': '1650um'}}}

# %% [markdown]
# It is important to note that in terms of component rendering in ANSYS, the components are drawn on an XY plane with its Z-coordinate being defined by 'center_z'. For the design object we just created, C_chip components are drawn at z=0, and the Q_chip components are drawn at 20 um.

# %%
design.chips["C_chip"]["size"]["center_z"]
# Out:
# '0.0mm'

# %%
design.chips["Q_chip"]["size"]["center_z"]
# Out:
# '20 um'

# %% [markdown]
# Next, we set the Q_chip to be at a distance of, say 10 um, from the C_chip.

# %%
design.chips["Q_chip"]["size"]["center_z"] = "10 um"
design.chips["Q_chip"]["size"]["center_z"]
# Out:
# '10 um'

# %% [markdown]
# It is possible that you would like to assign a new material to the chip substrate. In this case, I'd usually define a new material in the library instead of modifying the existing one. If this is not of interest, feel free to skip this part.
#
# Say, we would like to have a Silicon substrate with a different dielectric constant (11.45 instead of the default value of 11.9). Let's call this new material 'Si_11.45'.
#
# To do this, first we add the new material to the ANSYS material library (either manually or scripted like what we did below), and then specify the new material in the design object.

# %%
# new material properties
newMaterial_name = "Si_11.45"
newMaterial_permittivity = "11.45"
newMaterial_losstangent = "1e-7"

# %%
# add the new material via scripting
# uncomment if needed
from pyEPR import ansys, project_info

# get the handles to the ANSYS system
ans_prj = project_info.ProjectInfo()
oProject = ans_prj.project._project
defmanager = oProject.GetDefinitionManager()
# check if the material exists
if not defmanager.DoesMaterialExist(newMaterial_name):
    defmanager.AddMaterial(
        [
            "NAME:%s" % (newMaterial_name),
            "CoordinateSystemType:=",
            "Cartesian",
            "BulkOrSurfaceType:=",
            1,
            ["NAME:PhysicsTypes", "set:=", ["Electromagnetic"]],
            "permittivity:=",
            "%s" % (newMaterial_permittivity),
            "dielectric_loss_tangent:=",
            "%s" % (newMaterial_losstangent),
        ]
    )
# release the handle to ANSYS
ans_prj.project.release()
ans_prj.desktop.release()
ans_prj.app.release()
ansys.release()
# Out:
# INFO 04:52PM [connect_project]: Connecting to Ansys Desktop API...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       3 from pyEPR import ansys, project_info
#       5 # get the handles to the ANSYS system
# ----> 6 ans_prj = project_info.ProjectInfo()
#       7 oProject = ans_prj.project._project
#       8 defmanager = oProject.GetDefinitionManager()
#
# File ~/CODE_REPOS/quantum_hardware_all/qiskit-metal/.venv/lib/python3.11/site-packages/pyEPR/project_info.py:249, in ProjectInfo.__init__(self, project_path, project_name, design_name, setup_name, dielectrics_bulk, dielectric_surfaces, resistive_surfaces, seams, junctions, do_connect)
#     246 self.setup = None
#     248 if do_connect:
# --> 249     self.connect()
#     250     self.dissipative["pinfo"] = self
#
# File ~/CODE_REPOS/quantum_hardware_all/qiskit-metal/.venv/lib/python3.11/site-packages/pyEPR/project_info.py:434, in ProjectInfo.connect(self)
#     422 def connect(self) -> "ProjectInfo":
#     423     """Establish a full connection to the Ansys Desktop API.
#     424
#     425     Calls :meth:`connect_project`, :meth:`connect_design`, and
#    (...)    431         Returns ``self`` to allow chaining (e.g. ``pinfo = ProjectInfo(...).connect()``).
#     432     """
# --> 434     self.connect_project()
#     435     if not self.project:
#     436         logger.info("\tConnection to Ansys NOT established.  \n")
#
# File ~/CODE_REPOS/quantum_hardware_all/qiskit-metal/.venv/lib/python3.11/site-packages/pyEPR/project_info.py:291, in ProjectInfo.connect_project(self)
#     281 """Open the Ansys Desktop application and attach to the target project.
#     282
#     283 Sets ``self.app``, ``self.desktop``, ``self.project``,
#    (...)    287 in the running Ansys Desktop instance.
#     288 """
#     289 logger.info("Connecting to Ansys Desktop API...")
# --> 291 self.app, self.desktop, self.project = ansys.load_ansys_project(
#     292     self.project_name, self.project_path
#     293 )
#     295 if self.project:
#     296     # TODO: should be property?
#     297     self.project_name = self.project.name
#
# File ~/CODE_REPOS/quantum_hardware_all/qiskit-metal/.venv/lib/python3.11/site-packages/pyEPR/ansys.py:3782, in load_ansys_project(proj_name, project_path, extension)
#    3777     if (project_path / ".lock").is_file():
#    3778         logger.warning(
#    3779             "\t\tFile is locked. \N{FEARFUL FACE} If connection fails, delete the .lock file."
#    3780         )
# -> 3782 app = HfssApp()
#    3783 logger.info("\tOpened Ansys App")
#    3785 desktop = app.get_app_desktop()
#
# File ~/CODE_REPOS/quantum_hardware_all/qiskit-metal/.venv/lib/python3.11/site-packages/pyEPR/ansys.py:381, in HfssApp.__init__(self, ProgID)
#     370 """
#     371 Connect to IDispatch-based COM object.
#     372     Parameter is the ProgID or CLSID of the COM object.
#    (...)    378
#     379 """
#     380 super(HfssApp, self).__init__()
# --> 381 self._app = Dispatch(ProgID)
#
# NameError: name 'Dispatch' is not defined

# %%
# Specify the new material assigment for the chip
design.chips["C_chip"]["material"] = newMaterial_name
design.chips["Q_chip"]["material"] = newMaterial_name

# %% [markdown]
# ## 3.  Run EPR Analysis
# We proceed to run the EPR analysis. This follows closely tutorial 4.02 Eigenmode and EPR.
#
# First, we initialise an EPRanalysis class object, and update the ANSYS simulation setup.

# %%
from qiskit_metal.analyses.quantization import EPRanalysis

eig_fc = EPRanalysis(design, "hfss")
eig_fc.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'min_freq_ghz': 1,
#  'n_modes': 1,
#  'max_delta_f': 0.5,
#  'max_passes': 10,
#  'min_passes': 1,
#  'min_converged': 1,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj': '10 nH', 'Cj': '0 fF'}}

# %%
# update setup setting
eig_fc.sim.setup.max_passes = 20
eig_fc.sim.setup.vars.Lj = "10 nH"
# since we are analysing both the qubit and the resonator, we set the number of modes to be 2
eig_fc.sim.setup.n_modes = 2
# if there is not enough computational power, you can set a less stringent max_delta_f
eig_fc.sim.setup.max_delta_f = 1
eig_fc.sim.setup.min_freq_ghz = 1.5
# pass the name of the junction (for the EPR analysis purpose)
eig_fc.setup.junctions.jj.rect = "JJ_rect_Lj_Q1_rect_jj"
eig_fc.setup.junctions.jj.line = "JJ_Lj_Q1_rect_jj_"

eig_fc.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'min_freq_ghz': 1.5,
#  'n_modes': 2,
#  'max_delta_f': 1,
#  'max_passes': 20,
#  'min_passes': 1,
#  'min_converged': 1,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj': '10 nH', 'Cj': '0 fF'}}

# %% [markdown]
# Next, we run the ANSYS simulation and then the EPR analysis.

# %%
eig_fc.sim.run(
    name="qubitres", components=["Q1", "R1"], open_terminations=[], box_plus_buffer=True
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 eig_fc.sim.run(
#       2     name="qubitres", components=["Q1", "R1"], open_terminations=[], box_plus_buffer=True
#       3 )
#
# File ~/CODE_REPOS/quantum_hardware_all/qiskit-metal/src/qiskit_metal/analyses/core/simulation.py:203, in QSimulation.run(self, *args, **kwargs)
#     199 def run(self, *args, **kwargs):
#     200     """Alias for run_sim() necessary to implement super-class method, while
#     201     preventing method name collision when sim and non-sim QAnalysis classes are inherited.
#     202     """
# --> 203     self.run_sim(*args, **kwargs)
#
# File ~/CODE_REPOS/quantum_hardware_all/qiskit-metal/src/qiskit_metal/analyses/simulation/eigenmode.py:126, in EigenmodeSim.run_sim(self, name, components, open_terminations, port_list, jj_to_port, ignored_jjs, box_plus_buffer)
#     123 self.clear_data()
#     125 if not self.renderer_initialized:
# --> 126     self._initialize_renderer()
#     128 vars_to_initialize = self.setup.vars
#     129 renderer_design_name = self._render(
#     130     name=name,
#     131     solution_type="eigenmode",
#    (...)    138     vars_to_initialize=vars_to_initialize,
#     139 )
#
# File ~/CODE_REPOS/quantum_hardware_all/qiskit-metal/src/qiskit_metal/analyses/core/simulation.py:144, in QSimulation._initialize_renderer(self)
#     142 def _initialize_renderer(self):
#     143     """Starts the renderer by executing the routine of the selected renderer."""
# --> 144     self.renderer.start()
#
# File ~/CODE_REPOS/quantum_hardware_all/qiskit-metal/src/qiskit_metal/renderers/renderer_base/renderer_base.py:380, in QRenderer.start(self, force)
#     375         self._close_renderer()
#     377 # TODO: move the code line below to inside the `if force or not initiated`,
#     378 #  but only after the TODO before the `if` is completed
#     379 # try to initialize the renderer
# --> 380 self.initiated = self._initiate_renderer()
#     382 return self.initiated
#
# File ~/CODE_REPOS/quantum_hardware_all/qiskit-metal/src/qiskit_metal/renderers/renderer_ansys/ansys_renderer.py:341, in QAnsysRenderer._initiate_renderer(self)
#     339     self.rapp = HfssApp()
#     340 except NameError:
# --> 341     raise RuntimeError(
#     342         "\n\nCannot connect to Ansys HFSS — win32com (Windows COM) is not available.\n\n"
#     343         "This renderer requires:\n"
#     344         "  1. Microsoft Windows  (COM automation is Windows-only)\n"
#     345         "  2. Ansys Electronics Desktop (HFSS) installed and licensed\n"
#     346         "  3. pywin32 installed:  pip install pywin32\n\n"
#     347         "Running on macOS or Linux? Use one of these alternatives instead:\n"
#     348         "  • ElmerFEM open-source FEM:  see tutorial 4.19 (tutorials/4-Analysis/)\n"
#     349         "  • Export to GDS and simulate externally:  see tutorial 3.2\n"
#     350         "  • pyaedt-based renderer (Windows + Ansys 2022+):  QAnsysPyaedtRenderer\n"
#     351     ) from None
#     352 self.rdesktop = self.rapp.get_app_desktop()
#     353 if self.rdesktop.project_count() == 0:
#
# RuntimeError:
#
# Cannot connect to Ansys HFSS — win32com (Windows COM) is not available.
#
# This renderer requires:
#   1. Microsoft Windows  (COM automation is Windows-only)
#   2. Ansys Electronics Desktop (HFSS) installed and licensed
#   3. pywin32 installed:  pip install pywin32
#
# Running on macOS or Linux? Use one of these alternatives instead:
#   • ElmerFEM open-source FEM:  see tutorial 4.19 (tutorials/4-Analysis/)
#   • Export to GDS and simulate externally:  see tutorial 3.2
#   • pyaedt-based renderer (Windows + Ansys 2022+):  QAnsysPyaedtRenderer

# %%
eig_fc.setup.dissipatives.dielectrics_bulk = ["Q_chip", "C_chip"]
eig_fc.run_epr()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 eig_fc.setup.dissipatives.dielectrics_bulk = ["Q_chip", "C_chip"]
# ----> 2 eig_fc.run_epr()
#
# File ~/CODE_REPOS/quantum_hardware_all/qiskit-metal/src/qiskit_metal/analyses/quantization/energy_participation_ratio.py:174, in EPRanalysis.run_epr(self, no_junctions)
#     171 # wipe data from the previous run (if any)
#     172 self.clear_data()
# --> 174 self.get_stored_energy(no_junctions)
#     175 if not no_junctions:
#     176     self.run_analysis()
#
# File ~/CODE_REPOS/quantum_hardware_all/qiskit-metal/src/qiskit_metal/analyses/quantization/energy_participation_ratio.py:207, in EPRanalysis.get_stored_energy(self, no_junctions)
#     204 """Calculate the energy stored in the system based on the eigenmode results."""
#     205 # execute EPR and energy extraction
#     206 self.energy_elec, self.energy_elec_sub, self.energy_mag = (
# --> 207     self.sim.renderer.epr_get_stored_energy(**self.epr_start(no_junctions))
#     208 )
#     210 # present a human-friendly output
#     211 print(f"""
#     212 energy_elec_all       = {self.energy_elec}
#     213 energy_elec_substrate = {self.energy_elec_sub}
#    (...)    217 energy_mag % of energy_elec_all  = {self.energy_mag / self.energy_elec * 100:.1f}%
#     218 """)
#
# File ~/CODE_REPOS/quantum_hardware_all/qiskit-metal/src/qiskit_metal/renderers/renderer_ansys/ansys_renderer.py:1819, in QAnsysRenderer.epr_get_stored_energy(self, junctions, dissipatives)
#    1816 elif self.epr_distributed_analysis is None:
#    1817     self.epr_start()
# -> 1819 if self.pinfo.dissipative["dielectrics_bulk"] is not None:
#    1820     eprd = self.epr_distributed_analysis
#    1821     energy_elec = eprd.calc_energy_electric()
#
# AttributeError: 'NoneType' object has no attribute 'dissipative'

# %%
eig_fc.sim.close()
